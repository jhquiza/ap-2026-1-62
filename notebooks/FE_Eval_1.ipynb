# %% [markdown]
# # Fundamentos de Estadística - Evaluación 1

# %% [markdown]
# ## Carga de datos
#
# Se va a trabajar con un dataset que contiene información sobre ventas a domicilio de una tienda en Estados Unidos.
#
# Cárgue el archivo de  datos y verifique que se haya cargado correctamente.
#
# Las variables que son fechas deben convertirse a datos de tiempo.

# %% [markdown]
# De acuerdo a lo visto en clase, indique qué tipo de variable es cada una de las que están en el DataFrame.

# %% [markdown]
# ## Análisis de variables cualitativas
#
# De las variables cualitativas, identifique cuáles tienen alta cardinalidad. Excluya esta(s) de los análisis posteriores.
#
# Convierta a "category" las variables categóricas no descartadas, cuidando que las variables nominales y ordinales queden correctamente convertidas.

# %% [markdown]
# Haga las tablas de frecuencias porcentuales de todas las variables categóricas.
#
# Para cada variable, indique cuál es la categoría más frecuente y cuál la menos frecuente.
#
# Identifique qué variables presentan categorías atípicas. Indique los nombres de las categorías atípicas.

# %% [markdown]
# Para las variables nominales, haga un gráfico de barras horizontales de la tabla de frecuencia relativa, ordenados de forma descendente.
#
# Para las variables ordinales, haga un gráfico de barras verticales de la tabla de frecuencia relativa, ordenados de acuerdo al orden de las categorías.
#
# Para las variables ordinales, haga un gráfico de barras vertical de la tabla de frecuencia acumulada, ordenada de acuerdo al orden de las categorías.

# %% [markdown]
# ## Análisis de variables cuantitativas
#
# Identifique cuales variables son discretas, y cuales continuas. Para los análisis posteriores excluya las variables que son fechas.
#
# Para cada una de las variables discretas:
#
# - Haga un gráfico de barras horizontales de la función de masa empírica (frecuencia relativa), ordenado de acuerdo al orden de los valores que toma la variable.
# - Haga un gráfico de barras horizontales de la función de distribución acumulada empírica (frecuencia acumulada), ordenado de acuerdo al orden de los valores que toma la variable.
# - Calcule la media, la mediana y la moda.

# %% [markdown]
# Para cada una de las variables continuas:
#
# - Haga un histograma o un gráficos de densidad (el que prefiera, no los dos.
# - Analice la forma de la distribución de la variable (asimetría, dispersión, modalidad).
# - Calcule la curtosis y la asimetría e indique, de acuerdo a los resultados y a las gráficas, si son normales o no.
# - Presente las estadísticas más importantes.
# - Haga un gráfico de cajas y bigotes, e indique si la variable tiene valores atípicos.

# %% [markdown]
# ## Análisis bivariado
#
# Analice las relaciones entre las variables cuantitativas del dataset, exceptuando las fechas.

# %% [markdown]
# Analice las relaciones entre las variables cualitativas del dataset, exceptuando la variable "Sub-Category".

# %% [markdown]
# Analice las relaciones dfe cada una de las siguientes variables con respecto a la variable "Sales":
#
# - Year
# - Month
# - Region
# - Segment
# - Category
