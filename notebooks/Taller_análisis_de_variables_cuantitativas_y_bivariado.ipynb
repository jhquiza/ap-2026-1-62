# %% [markdown]
# # Taller análisis de variables cuantitativas y análisis bivariado
#
# Se va a trabajar con el dataset **auto-mpg**. Información sobre este se puede obtener en el [repositorio de datasets de ML de la Universidad de Irvine](https://archive.ics.uci.edu/dataset/9/auto+mpg).
#
# Ejecute la celda que está a continuación para cargar el dataset:

# %%
import pandas as pd

df = pd.read_csv(
    "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data-original",
    sep=r'\s+',
    header=None,
    names=['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin', 'car_name'])

df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0        8.0         307.0       130.0  3504.0          12.0
# 1  15.0        8.0         350.0       165.0  3693.0          11.5
# 2  18.0        8.0         318.0       150.0  3436.0          11.0
# 3  16.0        8.0         304.0       150.0  3433.0          12.0
# 4  17.0        8.0         302.0       140.0  3449.0          10.5
#
#    model_year  origin                   car_name
# 0        70.0     1.0  chevrolet chevelle malibu
# 1        70.0     1.0          buick skylark 320
# 2        70.0     1.0         plymouth satellite
# 3        70.0     1.0              amc rebel sst
# 4        70.0     1.0                ford torino

# %% [markdown]
# Identifique:
# - Variables cualitativas
# - Variables cuantitativas discretas
# - Variables cuantitativas continuas

# %% [markdown]
# ## Análisis de variables cuantitativas
#
# - Genere histogramas o gráficos de densidad para cada variable cuantitativa y analice la forma de su distribución.
# - Presente las estadísticas más importantes de cada variable.
# - Calcule la curtosis y la asimetría de cada variable e indique, de acuerdo a los resultados, si son normales o no.
# - Usando gráficos de caja y bigotes, indique qué variables presentan valores atípicos.

# %% [markdown]
# ## Análisis bivariado
#
# - Analice las relaciones entre las variables cuantitativas del dataset.
# - Analice las relaciones entre cada una de las variables cuantitativas y la variable **origin**.
# - Asumiendo que la variable **cylinders** es cualitativa, analice la relación entre esta y la variable **origin**.
