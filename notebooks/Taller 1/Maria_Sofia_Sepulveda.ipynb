# %% [markdown]
# # Taller análisis descriptivo de variables cualitativas

# %% [markdown]
# Se va a trabajar con un dataset que contiene información sobre incidentes de tránsito en Medellín con víctimas.
#
# Cárguelo y verifique que se haya cargado correctamente.

# %%
import pandas as pd
df = pd.read_csv('Accidentes')
df.head(10)
# Out:
#   Fecha_incidente Gravedad_victima Clase_incidente Sexo  \
# 0      2014-01-01          Heridos            Otro    M
# 1      2014-01-01          Heridos       Atropello    M
# 2      2014-01-01          Heridos       Atropello    F
# 3      2014-01-01          Heridos       Atropello    M
# 4      2014-01-01          Heridos       Atropello    M
# 5      2014-01-01          Heridos       Atropello    M
# 6      2014-01-01          Heridos       Atropello    M
# 7      2014-01-01          Heridos          Choque    M
# 8      2014-01-01          Heridos          Choque    F
# 9      2014-01-01          Heridos          Choque    M
#
#                     Condicion Grupo_edad                 Comuna  \
# 0                Motociclista    10 - 19          04 - Aranjuez
# 1                Motociclista    20 - 29           01 - Popular
# 2                      Peatón    10 - 19           01 - Popular
# 3                Motociclista    10 - 19             16 - Belén
# ...

# %% [markdown]
# La variable "Fecha_incidente" debe convertirse a dato de tiempo.
#
# Excluya los datos del año 2021.

# %%
df['Fecha_incidente'] = pd.to_datetime(df['Fecha_incidente'])
df = df[df['Fecha_incidente'].dt.year != 2021]
df["Año"] = df["Año"].astype(int)
df.head(-10)
# Out:
#        Fecha_incidente Gravedad_victima Clase_incidente Sexo  \
# 0           2014-01-01          Heridos            Otro    M
# 1           2014-01-01          Heridos       Atropello    M
# 2           2014-01-01          Heridos       Atropello    F
# 3           2014-01-01          Heridos       Atropello    M
# 4           2014-01-01          Heridos       Atropello    M
# ...                ...              ...             ...  ...
# 214101      2020-12-31          Heridos     Volcamiento    M
# 214102      2020-12-31          Heridos     Volcamiento    F
# 214103      2020-12-31          Heridos          Choque    M
# 214104      2020-12-31          Heridos       Atropello    F
# 214105      2020-12-31          Heridos       Atropello    F
#
#                          Condicion Grupo_edad           Comuna  \
# 0                     Motociclista    10 - 19    04 - Aranjuez
# 1                     Motociclista    20 - 29     01 - Popular
# ...

# %% [markdown]
# De acuerdo a lo visto en clase, indique qué tipo de variable es cada una de las que están en el DataFrame.
#
# Convierta a "category" las variables categóricas, cuidando que las variables nominales y ordinales queden correctamente convertidas.

# %% [markdown]
# ## Variables cualitativas:
#
#  - Gravedad_victima (nominal)
#  - Clase_incidente (nominal)
#  - Sexo (nominal)
#  - Condicion (nominal)
#  - Barrio (nominal)
#  - Comuna (nominal)
#  - Dia_semana (ordinal)
#  - Mes (ordinal)
#  - Grupo_edad (ordinal)
#
#  ## Variables cuantitativas:
#
#  - Año

# %%
df1 = df.copy()
df1["Gravedad_victima"] = df1["Gravedad_victima"].astype("category")
df1["Clase_incidente"] = df1["Clase_incidente"].astype("category")
df1["Sexo"] = df1["Sexo"].astype("category")
df1["Condicion"] = df1["Condicion"].astype("category")
df1["Comuna"] = df1["Comuna"].astype("category")
df1["Barrio"] = df1["Barrio"].astype("category")
df1["Grupo_edad"] = df1["Grupo_edad"].astype("category")
df1["Dia_semana"] = df1["Dia_semana"].astype("category")
df1["Mes"] = df1["Mes"].astype("category")
df1["Fecha_incidente"] = df1["Fecha_incidente"].astype("category")
df1["Año"] = df1["Año"].astype("category")
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 214116 entries, 0 to 214115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Fecha_incidente   214116 non-null  category
#  1   Gravedad_victima  214116 non-null  category
#  2   Clase_incidente   214116 non-null  category
#  3   Sexo              212482 non-null  category
#  4   Condicion         214116 non-null  category
#  5   Grupo_edad        211871 non-null  category
#  6   Comuna            195177 non-null  category
#  7   Barrio            195036 non-null  category
#  8   Dia_semana        214116 non-null  category
#  9   Mes               214116 non-null  category
#  10  Año               214116 non-null  category
# dtypes: category(11)
# memory usage: 4.4 MB

# %%
#df1["Mes"].unique()

# %%
df1['Grupo_edad'] = pd.Categorical(
    df1['Grupo_edad'],
    categories=['0 - 9','10 - 19', '20 - 29', '30 - 39', '40 - 49', '50 - 59', '60 - 69', '70 - 79', '80 o más'],
    ordered=True
    )
df1['Grupo_edad'].value_counts(sort=False)
# Out:
# Grupo_edad
# 0 - 9        5772
# 10 - 19     22361
# 20 - 29     85123
# 30 - 39     44693
# 40 - 49     28270
# 50 - 59     14366
# 60 - 69      6587
# 70 - 79      3338
# 80 o más     1361
# Name: count, dtype: int64

# %%
df1['Dia_semana'] = pd.Categorical(
    df1['Dia_semana'],
    categories=["Lunes","Martes", "Miércoles", "Jueves", "Viernes","Sábado", "Domingo"],
    ordered=True
    )

df1['Dia_semana'].value_counts(sort=False)
# Out:
# Dia_semana
# Lunes        30786
# Martes       31455
# Miércoles    31755
# Jueves       31392
# Viernes      31751
# Sábado       31179
# Domingo      25798
# Name: count, dtype: int64

# %%
df1['Mes'] = pd.Categorical(
    df1['Mes'],
    categories=["Enero","Febrero", "Marzo", "Abril", "Mayo","Junio", "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre","Diciembre"],
    ordered=True
    )
df1['Mes'].value_counts(sort=False)
# Out:
# Mes
# Enero         17030
# Febrero       18072
# Marzo         18159
# Abril         16024
# Mayo          17231
# Junio         17059
# Julio         18166
# Agosto        19133
# Septiembre    19093
# Octubre       18515
# Noviembre     17519
# Diciembre     18115
# Name: count, dtype: int64

# %% [markdown]
# Identifique qué variable(s) tienen alta cardinalidad. Excluya esta(s) de los análisis posteriores.

# %%
df1.describe(include=['object','category'])
# Out:
#             Fecha_incidente Gravedad_victima Clase_incidente    Sexo  \
# count                214116           214116          214116  212482
# unique                 2557                2               6       2
# top     2017-08-04 00:00:00          Heridos          Choque       M
# freq                    155           212341           94148  147373
#
#            Condicion Grupo_edad              Comuna  Barrio Dia_semana  \
# count         214116     211871              195177  195036     214116
# unique             7          9                  21     418          7
# top     Motociclista    20 - 29  10 - La Candelaria  Caribe  Miércoles
# freq          128669      85123               33631    3651      31755
#
#            Mes     Año
# count   214116  214116
# unique      12       7
# top     Agosto    2016
# freq     19133   33792

# %%
df_ok = df1.drop(columns= ["Fecha_incidente","Barrio"])
df_ok.head(10)
# Out:
#   Gravedad_victima Clase_incidente Sexo                   Condicion  \
# 0          Heridos            Otro    M                Motociclista
# 1          Heridos       Atropello    M                Motociclista
# 2          Heridos       Atropello    F                      Peatón
# 3          Heridos       Atropello    M                Motociclista
# 4          Heridos       Atropello    M                      Peatón
# 5          Heridos       Atropello    M                      Peatón
# 6          Heridos       Atropello    M                      Peatón
# 7          Heridos          Choque    M                Motociclista
# 8          Heridos          Choque    F  Acompañante de Motocicleta
# 9          Heridos          Choque    M                Motociclista
#
#   Grupo_edad                 Comuna Dia_semana    Mes   Año
# 0    10 - 19          04 - Aranjuez  Miércoles  Enero  2014
# 1    20 - 29           01 - Popular  Miércoles  Enero  2014
# ...

# %% [markdown]
# Haga las tablas de frecuencias porcentuales de todas las variables categóricas.
#
# Para cada variable, indique cuál es la categoría más frecuente y cuál la menos frecuente.
#
# Identifique qué variables presentan categorías atípicas. Indique los nombres de las categorías atípicas.

# %%
100*df_ok["Gravedad_victima"].value_counts(normalize=True)
# Out:
# Gravedad_victima
# Heridos    99.17101
# Muertos     0.82899
# Name: proportion, dtype: float64

# %% [markdown]
# En la variable Gravedad: victima, la categoria mas frecuente es Heridos y la menos frecuente es Muertos

# %%
100*df_ok["Clase_incidente"].value_counts(normalize=True)
# Out:
# Clase_incidente
# Choque            43.970558
# Otro              17.234583
# Atropello         16.960900
# Caida Ocupante    15.231930
# Volcamiento        6.591754
# Incendio           0.010275
# Name: proportion, dtype: float64

# %% [markdown]
# En la variable Clase_incidente, la categoria más frecuente es Choque, y la menos frecuente es Incendio

# %%
100*df_ok["Sexo"].value_counts(normalize=True)
# Out:
# Sexo
# M    69.357875
# F    30.642125
# Name: proportion, dtype: float64

# %% [markdown]
# En la variable Sexo, la categoria más frecuente es Masculino, y la menos frecuente es Femenino

# %%
100*df_ok["Condicion"].value_counts(normalize=True)
# Out:
# Condicion
# Motociclista                  60.093127
# Peatón                        13.921893
# Acompañante de Motocicleta    13.498291
# Pasajero                       5.835155
# Conductor                      2.659306
# Ciclista                       2.256254
# Acompañante de motocicleta     1.735975
# Name: proportion, dtype: float64

# %% [markdown]
# En la variable Condicion, la categoria más frecuente es Motociclista, y la menos frecuente es Acompañante de motociclista

# %%
100*df_ok["Grupo_edad"].value_counts(normalize=True, sort= False)
# Out:
# Grupo_edad
# 0 - 9        2.724299
# 10 - 19     10.554064
# 20 - 29     40.176806
# 30 - 39     21.094440
# 40 - 49     13.343025
# 50 - 59      6.780541
# 60 - 69      3.108967
# 70 - 79      1.575487
# 80 o más     0.642372
# Name: proportion, dtype: float64

# %% [markdown]
# En la variable Grupo_edad, la categoria más frecuente entre 20-29 años, y la menos frecuente es entre 80 o más

# %%
100*df_ok["Comuna"].value_counts(normalize=True)
# Out:
# Comuna
# 10 - La Candelaria                                 17.231026
# 05 - Castilla                                      10.754853
# 11 - Laureles Estadio                               9.339728
# 07 - Robledo                                        7.687894
# 04 - Aranjuez                                       6.830723
# 15 - Guayabal                                       6.799469
# 16 - Belén                                          6.370115
# 14 - El Poblado                                     5.726085
# 03 - Manrique                                       4.391399
# 09 - Buenos Aires                                   4.385763
# 06 - Doce de Octubre                                3.828320
# 08 - Villa Hermosa                                  3.584439
# 12 - La América                                     3.212981
# 13 - San Javier                                     2.280494
# 01 - Popular                                        2.012532
# ...

# %% [markdown]
# En la variable comuna, el dato mas frecuente es la comuna 10 - La candelari y el menos frecuente es la comuna 50 - Corregimiento de San Sebastian de Palmitas

# %%
100*df_ok["Dia_semana"].value_counts(normalize=True, sort= False)
# Out:
# Dia_semana
# Lunes        14.378188
# Martes       14.690635
# Miércoles    14.830746
# Jueves       14.661212
# Viernes      14.828878
# Sábado       14.561733
# Domingo      12.048609
# Name: proportion, dtype: float64

# %% [markdown]
# En la variable Dia_semana, el dato as frecunete es Miércoles y el menos frecuente es Domingo

# %%
100*df_ok["Mes"].value_counts(normalize=True)
# Out:
# Mes
# Agosto        8.935810
# Septiembre    8.917129
# Octubre       8.647182
# Julio         8.484186
# Marzo         8.480917
# Diciembre     8.460367
# Febrero       8.440285
# Noviembre     8.182013
# Mayo          8.047507
# Junio         7.967177
# Enero         7.953633
# Abril         7.483794
# Name: proportion, dtype: float64

# %% [markdown]
# De la variable "Mes", el dato que mas frecuente es Agosto y el que menos es Abril

# %%
100*df_ok["Año"].value_counts(normalize=True)
# Out:
# Año
# 2016    15.782099
# 2015    15.235667
# 2019    14.887257
# 2017    14.784976
# 2014    14.670085
# 2018    13.582357
# 2020    11.057558
# Name: proportion, dtype: float64

# %% [markdown]
# De la variable "Año", el dato que mas frecuente es 2016 y el que menos es 2020

# %% [markdown]
# Para las variables nominales, haga un gráfico de barras horizontales de la tabla de frecuencia relativa, ordenados de forma descendente.
#
# Para las variables ordinales, haga un gráfico de barras verticales de la tabla de frecuencia relativa, ordenados de acuerdo al orden de las categorías.

# %%
(100*df1['Gravedad_victima'].value_counts(normalize=True)).plot(kind='bar')
# Out:
# <Axes: xlabel='Gravedad_victima'>

# %%
(100*df1['Clase_incidente'].value_counts(normalize=True)).plot(kind='bar')
# Out:
# <Axes: xlabel='Clase_incidente'>

# %%
(100*df1['Sexo'].value_counts(normalize = True)).plot(kind='bar')
# Out:
# <Axes: xlabel='Sexo'>

# %%
(100*df1['Condicion'].value_counts(normalize = True)).plot(kind='bar')
# Out:
# <Axes: xlabel='Condicion'>

# %%
(100*df1['Comuna'].value_counts(normalize=True)).plot(kind='bar')
# Out:
# <Axes: xlabel='Comuna'>

# %%
(100*df1['Dia_semana'].value_counts(normalize=True,sort=False)).plot(kind='pie')
# Out:
# <Axes: ylabel='proportion'>

# %%
(100*df1['Mes'].value_counts(normalize=True,sort=False)).plot(kind='pie')
# Out:
# <Axes: ylabel='proportion'>

# %%
(100*df1['Grupo_edad'].value_counts(normalize=True, sort=False)).plot(kind='pie')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# Para las variables ordinales, haga un gráfico de barras vertical de la tabla de frecuencia acumulada, ordenada de acuerdo al orden de las categorías.
#
# Para las variables ordinales, calcule la mediana, y los quartiles 1, 2 y 3.

# %%
(100*df1['Dia_semana'].value_counts(normalize=True, sort=False).cumsum()).plot(kind="bar")
# Out:
# <Axes: xlabel='Dia_semana'>

# %%
(100*df1['Mes'].value_counts(normalize=True, sort=False).cumsum()).plot(kind="bar")
# Out:
# <Axes: xlabel='Mes'>

# %%
(100*df1['Grupo_edad'].value_counts(normalize=True, sort=False).cumsum()).plot(kind="bar")
# Out:
# <Axes: xlabel='Grupo_edad'>

# %%
df1['Dia_semana'].cat.categories[df1['Dia_semana'].cat.codes.median().astype(int)]
# Out:
# 'Jueves'

# %%
df1['Mes'].cat.categories[df1['Mes'].cat.codes.median().astype(int)]
# Out:
# 'Julio'

# %%
df1['Grupo_edad'].cat.categories[df1['Grupo_edad'].cat.codes.median().astype(int)]
# Out:
# '20 - 29'

# %%
df1['Dia_semana'].cat.categories[df1['Dia_semana'].cat.codes.quantile([0.25, 0.5, 0.75]).astype(int)]
# Out:
# Index(['Martes', 'Jueves', 'Sábado'], dtype='object')

# %%
df1['Mes'].cat.categories[df1['Mes'].cat.codes.quantile([0.25, 0.5, 0.75]).astype(int)]
# Out:
# Index(['Abril', 'Julio', 'Octubre'], dtype='object')

# %%
df1['Grupo_edad'].cat.categories[df1['Grupo_edad'].cat.codes.quantile([0.25, 0.5, 0.75]).astype(int)]
# Out:
# Index(['20 - 29', '20 - 29', '40 - 49'], dtype='object')

# %% [markdown]
# #HECHO POR MARIA SOFIA SEPULVEDA VILLA
