# %% [markdown]
# # Taller análisis descriptivo de variables cualitativas

# %% [markdown]
# Se va a trabajar con un dataset que contiene información sobre incidentes de tránsito en Medellín con víctimas.
#
# Cárguelo y verifique que se haya cargado correctamente.

# %%
import pandas as pd

df_accidentes = pd.read_csv("/content/Accidentes de tránsito en Medellín.csv")
df_accidentes.head()
# Out:
#   Fecha_incidente Gravedad_victima Clase_incidente Sexo     Condicion  \
# 0      2014-01-01          Heridos            Otro    M  Motociclista
# 1      2014-01-01          Heridos       Atropello    M  Motociclista
# 2      2014-01-01          Heridos       Atropello    F        Peatón
# 3      2014-01-01          Heridos       Atropello    M  Motociclista
# 4      2014-01-01          Heridos       Atropello    M        Peatón
#
#   Grupo_edad         Comuna                  Barrio Dia_semana    Mes   Año
# 0    10 - 19  04 - Aranjuez  Manrique Central No. 1  Miércoles  Enero  2014
# 1    20 - 29   01 - Popular             Moscú No. 2  Miércoles  Enero  2014
# 2    10 - 19   01 - Popular             Moscú No. 2  Miércoles  Enero  2014
# 3    10 - 19     16 - Belén            Las Mercedes  Miércoles  Enero  2014
# 4    30 - 39     16 - Belén            Las Mercedes  Miércoles  Enero  2014

# %%
df_accidentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235843 entries, 0 to 235842
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Fecha_incidente   235843 non-null  object
#  1   Gravedad_victima  235843 non-null  object
#  2   Clase_incidente   235843 non-null  object
#  3   Sexo              233366 non-null  object
#  4   Condicion         235843 non-null  object
#  5   Grupo_edad        233309 non-null  object
#  6   Comuna            214117 non-null  object
#  7   Barrio            213961 non-null  object
#  8   Dia_semana        235843 non-null  object
#  9   Mes               235843 non-null  object
#  10  Año               235843 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 19.8+ MB

# %% [markdown]
# La variable "Fecha_incidente" debe convertirse a dato de tiempo.
#
# Excluya los datos del año 2021.

# %%
df_accidentes["Fecha_incidente"] = pd.to_datetime(df_accidentes["Fecha_incidente"])
df_accidentes.tail()
# Out:
#        Fecha_incidente Gravedad_victima Clase_incidente Sexo  \
# 235838      2021-09-30          Heridos            Otro    M
# 235839      2021-09-30          Heridos            Otro    F
# 235840      2021-09-30          Heridos  Caida Ocupante    M
# 235841      2021-09-30          Heridos       Atropello    F
# 235842      2021-09-30          Heridos            Otro    M
#
#                          Condicion Grupo_edad              Comuna  \
# 235838                Motociclista    30 - 39  08 - Villa Hermosa
# 235839  Acompañante de motocicleta    20 - 29  08 - Villa Hermosa
# 235840  Acompañante de motocicleta    40 - 49       03 - Manrique
# 235841                      Peatón    50 - 59                 NaN
# 235842                Motociclista    20 - 29                 NaN
#
#                Barrio Dia_semana         Mes   Año
# 235838  Las Estancias     Jueves  Septiembre  2021
# 235839  Las Estancias     Jueves  Septiembre  2021
# 235840     Santa Inés     Jueves  Septiembre  2021
# 235841            NaN     Jueves  Septiembre  2021
# 235842            NaN     Jueves  Septiembre  2021

# %%
df_accidentes[df_accidentes["Fecha_incidente"]<"2021-01-01"].head()
# Out:
#   Fecha_incidente Gravedad_victima Clase_incidente Sexo     Condicion  \
# 0      2014-01-01          Heridos            Otro    M  Motociclista
# 1      2014-01-01          Heridos       Atropello    M  Motociclista
# 2      2014-01-01          Heridos       Atropello    F        Peatón
# 3      2014-01-01          Heridos       Atropello    M  Motociclista
# 4      2014-01-01          Heridos       Atropello    M        Peatón
#
#   Grupo_edad         Comuna                  Barrio Dia_semana    Mes   Año
# 0    10 - 19  04 - Aranjuez  Manrique Central No. 1  Miércoles  Enero  2014
# 1    20 - 29   01 - Popular             Moscú No. 2  Miércoles  Enero  2014
# 2    10 - 19   01 - Popular             Moscú No. 2  Miércoles  Enero  2014
# 3    10 - 19     16 - Belén            Las Mercedes  Miércoles  Enero  2014
# 4    30 - 39     16 - Belén            Las Mercedes  Miércoles  Enero  2014

# %% [markdown]
# De acuerdo a lo visto en clase, indique qué tipo de variable es cada una de las que están en el DataFrame.
#
# Convierta a "category" las variables categóricas, cuidando que las variables nominales y ordinales queden correctamente convertidas.

# %% [markdown]
# **Tipo de Variables**
#
#
# *   Fecha_incidente = Cuantitativa discreta de intervalo
# *   Gravedad_victima = nominal
# *   Clase_incidente = nominal
# *   Sexo = nominal
# *   Condicion = nominal
# *   Grupo_edad = ordinal
# *   Comuna = nominal
# *   Barrio = nominal
# *   Dia_semana = ordinal
# *   Mes = ordinal
# *   Año = ordinal

# %%
df_accidentes["Grupo_edad"].value_counts()
# Out:
# Grupo_edad
# 20 - 29     93511
# 30 - 39     50057
# 40 - 49     30914
# 10 - 19     23967
# 50 - 59     16160
# 60 - 69      7263
# 0 - 9        6365
# 70 - 79      3615
# 80 o más     1457
# Name: count, dtype: int64

# %%
df_accidentes["Gravedad_victima"] = df_accidentes["Gravedad_victima"].astype("category")
df_accidentes["Clase_incidente"] = df_accidentes["Clase_incidente"].astype("category")
df_accidentes["Sexo"] = df_accidentes["Sexo"].astype("category")
df_accidentes["Condicion"] = df_accidentes["Condicion"].astype("category")
df_accidentes["Comuna"] = df_accidentes["Comuna"].astype("category")

df_accidentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235843 entries, 0 to 235842
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Fecha_incidente   235843 non-null  datetime64[ns]
#  1   Gravedad_victima  235843 non-null  category
#  2   Clase_incidente   235843 non-null  category
#  3   Sexo              233366 non-null  category
#  4   Condicion         235843 non-null  category
#  5   Grupo_edad        233309 non-null  object
#  6   Comuna            214117 non-null  category
#  7   Barrio            213961 non-null  object
#  8   Dia_semana        235843 non-null  object
#  9   Mes               235843 non-null  object
#  10  Año               235843 non-null  int64
# dtypes: category(5), datetime64[ns](1), int64(1), object(4)
# memory usage: 11.9+ MB

# %%
df_accidentes["Grupo_edad"].unique()
# Out:
# array(['10 - 19', '20 - 29', '30 - 39', '40 - 49', '0 - 9', '50 - 59',
#        nan, '60 - 69', '70 - 79', '80 o más'], dtype=object)

# %%
df_accidentes["Grupo_edad"] = pd.Categorical(
    df_accidentes["Grupo_edad"],
    categories= ['0 - 9', '10 - 19', '20 - 29', '30 - 39', '40 - 49', '50 - 59', '60 - 69', '70 - 79', '80 o más'],
    ordered=True
    )
df_accidentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235843 entries, 0 to 235842
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Fecha_incidente   235843 non-null  datetime64[ns]
#  1   Gravedad_victima  235843 non-null  category
#  2   Clase_incidente   235843 non-null  category
#  3   Sexo              233366 non-null  category
#  4   Condicion         235843 non-null  category
#  5   Grupo_edad        233309 non-null  category
#  6   Comuna            214117 non-null  category
#  7   Barrio            213961 non-null  object
#  8   Dia_semana        235843 non-null  object
#  9   Mes               235843 non-null  object
#  10  Año               235843 non-null  int64
# dtypes: category(6), datetime64[ns](1), int64(1), object(3)
# memory usage: 10.3+ MB

# %%
df_accidentes["Dia_semana"] = pd.Categorical(df_accidentes["Dia_semana"],
categories= ["Lunes", "Martes", "Miércoles","Jueves","Viernes", "Sábado", "Domingo"],
    ordered=True
    )

df_accidentes["Mes"] = pd.Categorical(df_accidentes["Mes"],
categories= ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio", "Julio",
             "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"],
    ordered=True
    )

df_accidentes["Año"] = pd.Categorical(df_accidentes["Año"],
categories= [2014,2015,2016,2017,2018,2019,2020,2021],
    ordered=True
    )

df_accidentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235843 entries, 0 to 235842
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Fecha_incidente   235843 non-null  datetime64[ns]
#  1   Gravedad_victima  235843 non-null  category
#  2   Clase_incidente   235843 non-null  category
#  3   Sexo              233366 non-null  category
#  4   Condicion         235843 non-null  category
#  5   Grupo_edad        233309 non-null  category
#  6   Comuna            214117 non-null  category
#  7   Barrio            213961 non-null  object
#  8   Dia_semana        235843 non-null  category
#  9   Mes               235843 non-null  category
#  10  Año               235843 non-null  category
# dtypes: category(9), datetime64[ns](1), object(1)
# memory usage: 5.6+ MB

# %% [markdown]
# Identifique qué variable(s) tienen alta cardinalidad. Excluya esta(s) de los análisis posteriores.

# %%
df_accidentes.describe(include=["object", "category",])
# Out:
#        Gravedad_victima Clase_incidente    Sexo     Condicion Grupo_edad  \
# count            235843          235843  233366        235843     233309
# unique                2               6       2             7          9
# top             Heridos          Choque       M  Motociclista    20 - 29
# freq             233894          103383  161603        142167      93511
#
#                     Comuna  Barrio Dia_semana     Mes     Año
# count               214117  213961     235843  235843  235843
# unique                  21     423          7      12       8
# top     10 - La Candelaria  Caribe  Miércoles  Agosto    2016
# freq                 36985    3917      34914   21893   33792

# %%
df_accidentes.drop("Barrio", axis=1)
# Out:
#        Fecha_incidente Gravedad_victima Clase_incidente Sexo  \
# 0           2014-01-01          Heridos            Otro    M
# 1           2014-01-01          Heridos       Atropello    M
# 2           2014-01-01          Heridos       Atropello    F
# 3           2014-01-01          Heridos       Atropello    M
# 4           2014-01-01          Heridos       Atropello    M
# ...                ...              ...             ...  ...
# 235838      2021-09-30          Heridos            Otro    M
# 235839      2021-09-30          Heridos            Otro    F
# 235840      2021-09-30          Heridos  Caida Ocupante    M
# 235841      2021-09-30          Heridos       Atropello    F
# 235842      2021-09-30          Heridos            Otro    M
#
#                          Condicion Grupo_edad              Comuna Dia_semana  \
# 0                     Motociclista    10 - 19       04 - Aranjuez  Miércoles
# 1                     Motociclista    20 - 29        01 - Popular  Miércoles
# 2                           Peatón    10 - 19        01 - Popular  Miércoles
# 3                     Motociclista    10 - 19          16 - Belén  Miércoles
# 4                           Peatón    30 - 39          16 - Belén  Miércoles
# ...                            ...        ...                 ...        ...
# 235838                Motociclista    30 - 39  08 - Villa Hermosa     Jueves
# 235839  Acompañante de motocicleta    20 - 29  08 - Villa Hermosa     Jueves
# 235840  Acompañante de motocicleta    40 - 49       03 - Manrique     Jueves
# 235841                      Peatón    50 - 59                 NaN     Jueves
# 235842                Motociclista    20 - 29                 NaN     Jueves
#
#                Mes   Año
# 0            Enero  2014
# 1            Enero  2014
# 2            Enero  2014
# 3            Enero  2014
# 4            Enero  2014
# ...            ...   ...
# 235838  Septiembre  2021
# 235839  Septiembre  2021
# 235840  Septiembre  2021
# 235841  Septiembre  2021
# 235842  Septiembre  2021
#
# [235843 rows x 10 columns]

# %% [markdown]
# Haga las tablas de frecuencias porcentuales de todas las variables categóricas.
#
# Para cada variable, indique cuál es la categoría más frecuente y cuál la menos frecuente.
#
# Identifique qué variables presentan categorías atípicas. Indique los nombres de las categorías atípicas.

# %%
df_accidentes.describe(include=["category"])
# Out:
#        Gravedad_victima Clase_incidente    Sexo     Condicion Grupo_edad  \
# count            235843          235843  233366        235843     233309
# unique                2               6       2             7          9
# top             Heridos          Choque       M  Motociclista    20 - 29
# freq             233894          103383  161603        142167      93511
#
#                     Comuna Dia_semana     Mes     Año
# count               214117     235843  235843  235843
# unique                  21          7      12       8
# top     10 - La Candelaria  Miércoles  Agosto    2016
# freq                 36985      34914   21893   33792

# %% [markdown]
# Gravedad_victima = La categoría más frecuente es Heridos y la menos es Muerto.
# Clase_incidente = La categoría más frecuente es Choque y la menos es Incendio.
# Sexo = La categoría más frecuente es M y la menos es F.
# Condicion = La categoría más frecuente es Motociclista y la menos es Ciclista.
# Grupo_edad = La categoría más frecuente es 20-29 y la menos es 80 o más.
# Comuna = La categoría más frecuente es 10-La Candelaria y la menos es 50-Corregimiento de San Sebastian de Palmitas.
# Dia_semana = La categoría más frecuente es Miercoles y la menos es Domingo.
# Mes = La categoría más frecuente es Agosto y la menos es Noviembre.
# Año = La categoría más frecuente es 2026 y la menos es 2021.

# %%
df_accidentes['Año'].value_counts(normalize=True, sort=False)
# Out:
# Año
# 2014    0.133186
# 2015    0.138321
# 2016    0.143282
# 2017    0.134229
# 2018    0.123311
# 2019    0.135158
# 2020    0.100389
# 2021    0.092125
# Name: proportion, dtype: float64

# %% [markdown]
# **Valores atípicos**
#
# Gravedad_victima = Muertos
# Clase_incidente = Incendio
# Grupo_edad = 80 o más
# Comuna = 50 - Corregimiento de San Sebastián de Palmitas

# %% [markdown]
# Para las variables nominales, haga un gráfico de barras horizontales de la tabla de frecuencia relativa, ordenados de forma descendente.
#
# Para las variables ordinales, haga un gráfico de barras verticales de la tabla de frecuencia relativa, ordenados de acuerdo al orden de las categorías.

# %% [markdown]
# **GRÁFICO TABLA DE FRECUENCIA RELATIVAS A VARIABLES NOMINALES**

# %%
df_accidentes['Gravedad_victima'].value_counts(normalize=True, ascending=True).plot(kind='barh')
# Out:
# <Axes: ylabel='Gravedad_victima'>

# %%
df_accidentes['Clase_incidente'].value_counts(normalize=True, ascending=True).plot(kind='barh')
# Out:
# <Axes: ylabel='Clase_incidente'>

# %%
df_accidentes['Sexo'].value_counts(normalize=True, ascending=True).plot(kind='barh')
# Out:
# <Axes: ylabel='Sexo'>

# %%
df_accidentes['Condicion'].value_counts(normalize=True, ascending=True).plot(kind='barh')
# Out:
# <Axes: ylabel='Condicion'>

# %%
df_accidentes['Comuna'].value_counts(normalize=True, ascending=True).plot(kind='barh')
# Out:
# <Axes: ylabel='Comuna'>

# %% [markdown]
# **GRÁFICO TABLA DE FRECUENCIA RELATIVAS A VARIABLES ORDINALES**

# %% [markdown]
# Grupo_edad = ordinal
# Dia_semana = ordinal
# Mes = ordinal
# Año = ordinal

# %%
df_accidentes['Grupo_edad'].value_counts(sort=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Grupo_edad'>

# %%
df_accidentes['Dia_semana'].value_counts(sort=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Dia_semana'>

# %%
df_accidentes['Mes'].value_counts(sort=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Mes'>

# %% [markdown]
# Para las variables ordinales, haga un gráfico de barras vertical de la tabla de frecuencia acumulada, ordenada de acuerdo al orden de las categorías.
#
# Para las variables ordinales, calcule la mediana, y los quartiles 1, 2 y 3.
