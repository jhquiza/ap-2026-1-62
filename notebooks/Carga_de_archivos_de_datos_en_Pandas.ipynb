# %% [markdown]
# # Carga de archivos de datos en Pandas

# %% [markdown]
# Es bastante usual que los conjuntos de datos estén en formato de archivo csv, donde los valores están separados por comas. Estas tablas pueden tener o no encabezados e índices. Pandas por defecto asume que la primera fila es de encabezados.

# %%
import pandas as pd

df = pd.read_csv("/content/home_data.csv")
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# Pandas identifica automáticamente el tipo de datos que contienen cada columna.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(16), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# Si no estamos de acuerdo con el tipo de dato que identificó Pandas, se puede cambiar con el método `.astype()`. Por ejemplo, si queremos convertir la columna `id` a string, podemos hacerlo de la siguiente manera:

# %%
df = df.astype({'id':'str'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  object
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(15), object(2)
# memory usage: 3.5+ MB

# %%
df = df.astype({'id':'int64'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(16), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# Un tipo especial de dato son las fechas, que son datos de tiempo. En este dataset la variable `date` es de este tipo, por lo que hay cambiarlo a datetime, usando el método `pd.to_datetime()`.

# %%
df['date'] = pd.to_datetime(
    df['date'],
    #dayfirst=False
    )
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#                id       date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018 2014-05-21  360000         3       2.50         1530
# 21609  6600060120 2015-02-23  400000         4       2.50         2310
# 21610  1523300141 2014-06-23  402101         2       0.75         1020
# 21611   291310100 2015-01-16  400000         3       2.50         1600
# 21612  1523300157 2014-10-15  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 21608              0      2009             0    98103  47.6993 -122.346
# 21609              0      2014             0    98146  47.5107 -122.362
# 21610              0      2009             0    98144  47.5944 -122.299
# 21611              0      2004             0    98027  47.5345 -122.069
# 21612              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 21608           1530        1509
# 21609           1830        7200
# 21610           1020        2007
# 21611           1410        1287
# 21612           1020        1357
#
# [5 rows x 21 columns]

# %% [markdown]
# # Indexación y slicing

# %% [markdown]
# En Pandas cada fila tiene un índice que la identifica. Es posible convertir una columna en índices, lo que puede ser útil para acceder a filas específicas.

# %%
df.set_index('id', inplace=True)
df.head()
# Out:
#                  date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520 2014-10-13  221900         3       1.00         1180      5650
# 6414100192 2014-12-09  538000         3       2.25         2570      7242
# 5631500400 2015-02-25  180000         2       1.00          770     10000
# 2487200875 2014-12-09  604000         4       3.00         1960      5000
# 1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520     1.0           0     0          3      7        1180
# 6414100192     2.0           0     0          3      7        2170
# 5631500400     1.0           0     0          3      6         770
# 2487200875     1.0           0     0          5      7        1050
# 1954400510     1.0           0     0          3      8        1680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 6414100192            400      1951          1991    98125  47.7210 -122.319
# 5631500400              0      1933             0    98028  47.7379 -122.233
# 2487200875            910      1965             0    98136  47.5208 -122.393
# 1954400510              0      1987             0    98074  47.6168 -122.045
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 6414100192           1690        7639
# 5631500400           2720        8062
# 2487200875           1360        5000
# 1954400510           1800        7503

# %% [markdown]
# Para extraer filas se deben usar los atributos `loc[ ]` y `iloc[ ]`. El primero usa los índices establecidos por el programador, conocidos en este contexto como **índices explícitos**, y el segundo usa el **número de fila o filas**, conocidos como **índices implícitos**.

# %%
df.loc[5631500400]
# Out:
# date             2015-02-25 00:00:00
# price                         180000
# bedrooms                           2
# bathrooms                        1.0
# sqft_living                      770
# sqft_lot                       10000
# floors                           1.0
# waterfront                         0
# view                               0
# condition                          3
# grade                              6
# sqft_above                       770
# sqft_basement                      0
# yr_built                        1933
# yr_renovated                       0
# zipcode                        98028
# lat                          47.7379
# long                        -122.233
# sqft_living15                   2720
# sqft_lot15                      8062
# Name: 5631500400, dtype: object

# %%
df.iloc[2]
# Out:
# date             2015-02-25 00:00:00
# price                         180000
# bedrooms                           2
# bathrooms                        1.0
# sqft_living                      770
# sqft_lot                       10000
# floors                           1.0
# waterfront                         0
# view                               0
# condition                          3
# grade                              6
# sqft_above                       770
# sqft_basement                      0
# yr_built                        1933
# yr_renovated                       0
# zipcode                        98028
# lat                          47.7379
# long                        -122.233
# sqft_living15                   2720
# sqft_lot15                      8062
# Name: 5631500400, dtype: object

# %%
df.iloc[0:2]
# Out:
#                  date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520 2014-10-13  221900         3       1.00         1180      5650
# 6414100192 2014-12-09  538000         3       2.25         2570      7242
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520     1.0           0     0          3      7        1180
# 6414100192     2.0           0     0          3      7        2170
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 6414100192            400      1951          1991    98125  47.7210 -122.319
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 6414100192           1690        7639

# %%
df.loc[7129300520:5631500400]
# Out:
#                  date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520 2014-10-13  221900         3       1.00         1180      5650
# 6414100192 2014-12-09  538000         3       2.25         2570      7242
# 5631500400 2015-02-25  180000         2       1.00          770     10000
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520     1.0           0     0          3      7        1180
# 6414100192     2.0           0     0          3      7        2170
# 5631500400     1.0           0     0          3      6         770
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 6414100192            400      1951          1991    98125  47.7210 -122.319
# 5631500400              0      1933             0    98028  47.7379 -122.233
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 6414100192           1690        7639
# 5631500400           2720        8062

# %% [markdown]
# Cuando no se tienen índices explícitos, se puede usar tanto `.iloc` como `.loc` con índices implícitos.

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df.loc[:3]
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
#
# [4 rows x 21 columns]

# %%
df.iloc[:3]
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
#
# [3 rows x 21 columns]

# %% [markdown]
# A las columnas se puede acceder usando los nombres.

# %%
df[['price','bedrooms','zipcode']]
# Out:
#         price  bedrooms  zipcode
# 0      221900         3    98178
# 1      538000         3    98125
# 2      180000         2    98028
# 3      604000         4    98136
# 4      510000         3    98074
# ...       ...       ...      ...
# 21608  360000         3    98103
# 21609  400000         4    98146
# 21610  402101         2    98144
# 21611  400000         3    98027
# 21612  325000         2    98144
#
# [21613 rows x 3 columns]

# %% [markdown]
# Para seleccionar varias columnas se deben pasar los nombres en una lista.

# %%
df[['id', 'date', 'price']]
# Out:
#                id       date   price
# 0      7129300520 2014-10-13  221900
# 1      6414100192 2014-12-09  538000
# 2      5631500400 2015-02-25  180000
# 3      2487200875 2014-12-09  604000
# 4      1954400510 2015-02-18  510000
# ...           ...        ...     ...
# 21608   263000018 2014-05-21  360000
# 21609  6600060120 2015-02-23  400000
# 21610  1523300141 2014-06-23  402101
# 21611   291310100 2015-01-16  400000
# 21612  1523300157 2014-10-15  325000
#
# [21613 rows x 3 columns]

# %% [markdown]
# No se puede hacer *slicing* con las columnas directamente, pero se puede hacer con el método `loc`.

# %%
#df['id':'price']

# %%
df.loc[:, 'id':'price'].head()
# Out:
#            id       date   price
# 0  7129300520 2014-10-13  221900
# 1  6414100192 2014-12-09  538000
# 2  5631500400 2015-02-25  180000
# 3  2487200875 2014-12-09  604000
# 4  1954400510 2015-02-18  510000

# %% [markdown]
# Para borrar filas o columnas se usa el método .drop().

# %%
df.drop('sqft_living15', axis=1).head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_lot15
# 0      1955             0    98178  47.5112 -122.257        5650
# 1      1951          1991    98125  47.7210 -122.319        7639
# 2      1933             0    98028  47.7379 -122.233        8062
# 3      1965             0    98136  47.5208 -122.393        5000
# 4      1987             0    98074  47.6168 -122.045        7503

# %%
df.drop(2, axis=0).head()
# Out:
#            id       date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13   221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09   538000         3       2.25         2570      7242
# 3  2487200875 2014-12-09   604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18   510000         3       2.00         1680      8080
# 5  7237550310 2014-05-12  1225000         4       4.50         5420    101930
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
# 5     1.0           0     0  ...     11        3890           1530      2001
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
# 5             0    98053  47.6561 -122.005           4760      101930
#
# [5 rows x 21 columns]

# %%
df.drop(columns=['long'])
# Out:
#                id       date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900         3       1.00         1180
# 1      6414100192 2014-12-09  538000         3       2.25         2570
# 2      5631500400 2015-02-25  180000         2       1.00          770
# 3      2487200875 2014-12-09  604000         4       3.00         1960
# 4      1954400510 2015-02-18  510000         3       2.00         1680
# ...           ...        ...     ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000         3       2.50         1530
# 21609  6600060120 2015-02-23  400000         4       2.50         2310
# 21610  1523300141 2014-06-23  402101         2       0.75         1020
# 21611   291310100 2015-01-16  400000         3       2.50         1600
# 21612  1523300157 2014-10-15  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0          5650     1.0           0     0          3      7        1180
# 1          7242     2.0           0     0          3      7        2170
# 2         10000     1.0           0     0          3      6         770
# 3          5000     1.0           0     0          5      7        1050
# 4          8080     1.0           0     0          3      8        1680
# ...         ...     ...         ...   ...        ...    ...         ...
# 21608      1131     3.0           0     0          3      8        1530
# 21609      5813     2.0           0     0          3      8        2310
# 21610      1350     2.0           0     0          3      7        1020
# 21611      2388     2.0           0     0          3      8        1600
# 21612      1076     2.0           0     0          3      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat  sqft_living15  \
# 0                  0      1955             0    98178  47.5112           1340
# 1                400      1951          1991    98125  47.7210           1690
# 2                  0      1933             0    98028  47.7379           2720
# 3                910      1965             0    98136  47.5208           1360
# 4                  0      1987             0    98074  47.6168           1800
# ...              ...       ...           ...      ...      ...            ...
# 21608              0      2009             0    98103  47.6993           1530
# 21609              0      2014             0    98146  47.5107           1830
# 21610              0      2009             0    98144  47.5944           1020
# 21611              0      2004             0    98027  47.5345           1410
# 21612              0      2008             0    98144  47.5941           1020
#
#        sqft_lot15
# 0            5650
# 1            7639
# 2            8062
# 3            5000
# 4            7503
# ...           ...
# 21608        1509
# 21609        7200
# 21610        2007
# 21611        1287
# 21612        1357
#
# [21613 rows x 20 columns]

# %%
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df = df.drop(columns=['long'])
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat  sqft_living15  sqft_lot15
# 0      1955             0    98178  47.5112           1340        5650
# 1      1951          1991    98125  47.7210           1690        7639
# 2      1933             0    98028  47.7379           2720        8062
# 3      1965             0    98136  47.5208           1360        5000
# 4      1987             0    98074  47.6168           1800        7503

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  sqft_living15  21613 non-null  int64
#  19  sqft_lot15     21613 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(16)
# memory usage: 3.3 MB

# %%
df.drop(columns=['lat'], inplace=True)
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15
# 0      1955             0    98178           1340        5650
# 1      1951          1991    98125           1690        7639
# 2      1933             0    98028           2720        8062
# 3      1965             0    98136           1360        5000
# 4      1987             0    98074           1800        7503

# %%
df1 = df.copy()
df1.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15
# 0      1955             0    98178           1340        5650
# 1      1951          1991    98125           1690        7639
# 2      1933             0    98028           2720        8062
# 3      1965             0    98136           1360        5000
# 4      1987             0    98074           1800        7503

# %%
df1.drop(columns=['condition'], inplace=True)
df1.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0      7        1180              0      1955
# 1     2.0           0     0      7        2170            400      1951
# 2     1.0           0     0      6         770              0      1933
# 3     1.0           0     0      7        1050            910      1965
# 4     1.0           0     0      8        1680              0      1987
#
#    yr_renovated  zipcode  sqft_living15  sqft_lot15
# 0             0    98178           1340        5650
# 1          1991    98125           1690        7639
# 2             0    98028           2720        8062
# 3             0    98136           1360        5000
# 4             0    98074           1800        7503

# %%
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15
# 0      1955             0    98178           1340        5650
# 1      1951          1991    98125           1690        7639
# 2      1933             0    98028           2720        8062
# 3      1965             0    98136           1360        5000
# 4      1987             0    98074           1800        7503

# %% [markdown]
# Se puede hacer slicing, o filtrado, usando operadores lógicos y de comparación.

# %%
df['bedrooms']>=4
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 21608    False
# 21609     True
# 21610    False
# 21611    False
# 21612    False
# Name: bedrooms, Length: 21613, dtype: bool

# %%
df[df['bedrooms']>=4].head()
# Out:
#             id       date    price  bedrooms  bathrooms  sqft_living  \
# 3   2487200875 2014-12-09   604000         4        3.0         1960
# 5   7237550310 2014-05-12  1225000         4        4.5         5420
# 14  1175000570 2015-03-12   530000         5        2.0         1810
# 15  9297300055 2015-01-24   650000         4        3.0         2950
# 17  6865200140 2014-05-29   485000         4        1.0         1600
#
#     sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 3       5000     1.0           0     0          5      7        1050
# 5     101930     1.0           0     0          3     11        3890
# 14      4850     1.5           0     0          3      7        1810
# 15      5000     2.0           0     3          3      9        1980
# 17      4300     1.5           0     0          4      7        1600
#
#     sqft_basement  yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15
# 3             910      1965             0    98136           1360        5000
# 5            1530      2001             0    98053           4760      101930
# 14              0      1900             0    98107           1360        4850
# 15            970      1979             0    98126           2140        4000
# 17              0      1916             0    98103           1610        4300

# %%
df[df['date'] > '2015-03'].head()
# Out:
#             id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 8   2414600126 2015-04-15  229500         3        1.0         1780      7470
# 9   3793500160 2015-03-12  323000         3        2.5         1890      6560
# 10  1736800520 2015-04-03  662500         3        2.5         3560      9796
# 14  1175000570 2015-03-12  530000         5        2.0         1810      4850
# 19  7983200060 2015-04-24  230000         3        1.0         1250      9774
#
#     floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 8      1.0           0     0          3      7        1050            730
# 9      2.0           0     0          3      7        1890              0
# 10     1.0           0     0          3      8        1860           1700
# 14     1.5           0     0          3      7        1810              0
# 19     1.0           0     0          4      7        1250              0
#
#     yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15
# 8       1960             0    98146           1780        8113
# 9       2003             0    98038           2390        7570
# 10      1965             0    98007           2210        8925
# 14      1900             0    98107           1360        4850
# 19      1969             0    98003           1280        8850

# %% [markdown]
# # Operaciones entre columnas de un DataFrame, y ordenación por valores

# %% [markdown]
# Pandas permite crear nuevas columnas a partir de la realización de operaciones matemáticas entre columnas, o de operaciones con funciones de agregación.

# %%
df['temp'] = 0
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15  temp
# 0      1955             0    98178           1340        5650     0
# 1      1951          1991    98125           1690        7639     0
# 2      1933             0    98028           2720        8062     0
# 3      1965             0    98136           1360        5000     0
# 4      1987             0    98074           1800        7503     0

# %%
df['price_area_relation'] = df.price/df.sqft_living
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
#    yr_renovated  zipcode  sqft_living15  sqft_lot15  temp  price_area_relation
# 0             0    98178           1340        5650     0           188.050847
# 1          1991    98125           1690        7639     0           209.338521
# 2             0    98028           2720        8062     0           233.766234
# 3             0    98136           1360        5000     0           308.163265
# 4             0    98074           1800        7503     0           303.571429
#
# [5 rows x 21 columns]

# %%
df['standard_lot_area'] = (df.sqft_lot - df.sqft_lot.mean())/df.sqft_lot.std()
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...        1180              0      1955
# 1     2.0           0     0  ...        2170            400      1951
# 2     1.0           0     0  ...         770              0      1933
# 3     1.0           0     0  ...        1050            910      1965
# 4     1.0           0     0  ...        1680              0      1987
#
#    yr_renovated  zipcode  sqft_living15  sqft_lot15  temp  \
# 0             0    98178           1340        5650     0
# 1          1991    98125           1690        7639     0
# 2             0    98028           2720        8062     0
# 3             0    98136           1360        5000     0
# 4             0    98074           1800        7503     0
#
#    price_area_relation  standard_lot_area
# 0           188.050847          -0.228316
# 1           209.338521          -0.189881
# 2           233.766234          -0.123296
# 3           308.163265          -0.244009
# 4           303.571429          -0.169649
#
# [5 rows x 22 columns]

# %% [markdown]
# Es posible reordenar un DataFrame por valores de columnas o de índices.

# %%
df.sort_values('date')
# Out:
#                id       date    price  bedrooms  bathrooms  sqft_living  \
# 16768  5561000190 2014-05-02   437500         3       2.25         1970
# 9596    472000620 2014-05-02   790000         3       2.50         2600
# 9587   1024069009 2014-05-02   675000         5       2.50         2820
# 20602  7853361370 2014-05-02   555000         4       2.50         3310
# 11577  5056500260 2014-05-02   440000         4       2.25         2160
# ...           ...        ...      ...       ...        ...          ...
# 7898   1422700040 2015-05-14   183000         3       1.00         1170
# 928    8730000270 2015-05-14   359000         2       2.75         1370
# 5637   7923600250 2015-05-15   450000         5       2.00         1870
# 13053  5101400871 2015-05-24   445500         2       1.75         1390
# 16594  9106000005 2015-05-27  1310000         4       2.25         3750
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 16768     35100     2.0           0     0  ...        1970              0
# 9596       4750     1.0           0     0  ...        1700            900
# 9587      67518     2.0           0     0  ...        2820              0
# 20602      6500     2.0           0     0  ...        3310              0
# 11577      8119     1.0           0     0  ...        1080           1080
# ...         ...     ...         ...   ...  ...         ...            ...
# 7898       7320     1.0           0     0  ...        1170              0
# 928        1140     2.0           0     0  ...        1080            290
# 5637       7344     1.5           0     0  ...        1870              0
# 13053      6670     1.0           0     0  ...         720            670
# 16594      5000     2.0           0     0  ...        2440           1310
#
#        yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15  temp  \
# 16768      1977             0    98027           2340       35100     0
# 9596       1951             0    98117           2380        4750     0
# 9587       1979             0    98029           2820       48351     0
# 20602      2012             0    98065           2380        5000     0
# 11577      1966             0    98006           1850        9000     0
# ...         ...           ...      ...            ...         ...   ...
# 7898       1962             0    98188           2040        7320     0
# 928        2009             0    98133           1370        1090     0
# 5637       1960             0    98007           1870        7650     0
# 13053      1941             0    98115            920        6380     0
# 16594      1924             0    98115           2170        4590     0
#
#        price_area_relation  standard_lot_area
# 16768           222.081218           0.482684
# 9596            303.846154          -0.250044
# 9587            239.361702           1.265340
# 20602           167.673716          -0.207795
# 11577           203.703704          -0.168708
# ...                    ...                ...
# 7898            156.410256          -0.187998
# 928             262.043796          -0.337199
# 5637            240.641711          -0.187418
# 13053           320.503597          -0.203691
# 16594           349.333333          -0.244009
#
# [21613 rows x 22 columns]

# %%
df2 = df.sort_values('date', ascending=False, ignore_index=True).copy()
df2.head()
# Out:
#            id       date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  9106000005 2015-05-27  1310000         4       2.25         3750      5000
# 1  5101400871 2015-05-24   445500         2       1.75         1390      6670
# 2  7923600250 2015-05-15   450000         5       2.00         1870      7344
# 3  8730000270 2015-05-14   359000         2       2.75         1370      1140
# 4  9178601660 2015-05-14  1695000         5       3.00         3320      5354
#
#    floors  waterfront  view  ...  sqft_above  sqft_basement  yr_built  \
# 0     2.0           0     0  ...        2440           1310      1924
# 1     1.0           0     0  ...         720            670      1941
# 2     1.5           0     0  ...        1870              0      1960
# 3     2.0           0     0  ...        1080            290      2009
# 4     2.0           0     0  ...        3320              0      2004
#
#    yr_renovated  zipcode  sqft_living15  sqft_lot15  temp  \
# 0             0    98115           2170        4590     0
# 1             0    98115            920        6380     0
# 2             0    98007           1870        7650     0
# 3             0    98133           1370        1090     0
# 4             0    98103           2330        4040     0
#
#    price_area_relation  standard_lot_area
# 0           349.333333          -0.244009
# 1           320.503597          -0.203691
# 2           240.641711          -0.187418
# 3           262.043796          -0.337199
# 4           510.542169          -0.235462
#
# [5 rows x 22 columns]

# %%
df2.head()
# Out:
#            id       date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  9106000005 2015-05-27  1310000         4       2.25         3750      5000
# 1  5101400871 2015-05-24   445500         2       1.75         1390      6670
# 2  7923600250 2015-05-15   450000         5       2.00         1870      7344
# 3  8730000270 2015-05-14   359000         2       2.75         1370      1140
# 4  9178601660 2015-05-14  1695000         5       3.00         3320      5354
#
#    floors  waterfront  view  ...  sqft_above  sqft_basement  yr_built  \
# 0     2.0           0     0  ...        2440           1310      1924
# 1     1.0           0     0  ...         720            670      1941
# 2     1.5           0     0  ...        1870              0      1960
# 3     2.0           0     0  ...        1080            290      2009
# 4     2.0           0     0  ...        3320              0      2004
#
#    yr_renovated  zipcode  sqft_living15  sqft_lot15  temp  \
# 0             0    98115           2170        4590     0
# 1             0    98115            920        6380     0
# 2             0    98007           1870        7650     0
# 3             0    98133           1370        1090     0
# 4             0    98103           2330        4040     0
#
#    price_area_relation  standard_lot_area
# 0           349.333333          -0.244009
# 1           320.503597          -0.203691
# 2           240.641711          -0.187418
# 3           262.043796          -0.337199
# 4           510.542169          -0.235462
#
# [5 rows x 22 columns]

# %%
df.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...        1180              0      1955
# 1     2.0           0     0  ...        2170            400      1951
# 2     1.0           0     0  ...         770              0      1933
# 3     1.0           0     0  ...        1050            910      1965
# 4     1.0           0     0  ...        1680              0      1987
#
#    yr_renovated  zipcode  sqft_living15  sqft_lot15  temp  \
# 0             0    98178           1340        5650     0
# 1          1991    98125           1690        7639     0
# 2             0    98028           2720        8062     0
# 3             0    98136           1360        5000     0
# 4             0    98074           1800        7503     0
#
#    price_area_relation  standard_lot_area
# 0           188.050847          -0.228316
# 1           209.338521          -0.189881
# 2           233.766234          -0.123296
# 3           308.163265          -0.244009
# 4           303.571429          -0.169649
#
# [5 rows x 22 columns]

# %%
df.set_index('id').sort_index().drop(columns=['temp']).head(10)
# Out:
#               date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 1000102 2015-04-22  300000         6       3.00         2400      9373
# 1000102 2014-09-16  280000         6       3.00         2400      9373
# 1200019 2014-05-08  647500         4       1.75         2060     26036
# 1200021 2014-08-11  400000         3       1.00         1460     43000
# 2800031 2015-04-01  235000         3       1.00         1430      7599
# 3600057 2015-03-19  402500         4       2.00         1650      3504
# 3600072 2015-03-30  680000         4       2.75         2220      5310
# 3800008 2015-02-24  178000         5       1.50         1990     18200
# 5200087 2014-07-09  487000         4       2.50         2540      5001
# 6200017 2014-11-12  281000         3       1.00         1340     21336
#
#          floors  waterfront  view  condition  grade  sqft_above  \
# id
# 1000102     2.0           0     0          3      7        2400
# 1000102     2.0           0     0          3      7        2400
# 1200019     1.0           0     0          4      8        1160
# 1200021     1.0           0     0          3      7        1460
# 2800031     1.5           0     0          4      6        1010
# 3600057     1.0           0     0          3      7         760
# 3600072     1.0           0     0          5      7        1170
# 3800008     1.0           0     0          3      7        1990
# 5200087     2.0           0     0          3      9        2540
# 6200017     1.5           0     0          4      5        1340
#
#          sqft_basement  yr_built  yr_renovated  zipcode  sqft_living15  \
# id
# 1000102              0      1991             0    98002           2060
# 1000102              0      1991             0    98002           2060
# 1200019            900      1947             0    98166           2590
# 1200021              0      1952             0    98166           2250
# 2800031            420      1930             0    98168           1290
# 3600057            890      1951          2013    98144           1480
# 3600072           1050      1951             0    98144           1540
# 3800008              0      1960             0    98178           1860
# 5200087              0      2005             0    98108           2360
# 6200017              0      1945             0    98032           1340
#
#          sqft_lot15  price_area_relation  standard_lot_area
# id
# 1000102        7316           125.000000          -0.138433
# 1000102        7316           116.666667          -0.138433
# 1200019       21891           314.320388           0.263856
# 1200021       20023           273.972603           0.673411
# 2800031       10320           164.335664          -0.181262
# 3600057        3504           243.939394          -0.280126
# 3600072        4200           306.306306          -0.236525
# 3800008        8658            89.447236           0.074674
# 5200087        6834           191.732283          -0.243985
# 6200017       37703           209.701493           0.150385

# %% [markdown]
# # Carga de datos de archivos csv que no vienen en formato estándar

# %% [markdown]
# El método `read_csv()` de Pandas asume que los valores en cada fila están separados por comas, y que la primera fila es de encabezado, es decir, contiene los nombres de las variables. Si no es así, se deben modificar las opciones por defecto. Veamos un caso.

# %%
df = pd.read_csv("/content/auto-mpg.data")
df.head()
# Out:
#   18.0   8.   307.0      130.0      3504.      12.0   70.  1.\t"chevrolet chevelle malibu"
# 0  15.0   8.   350.0      165.0      3693.      1...
# 1  18.0   8.   318.0      150.0      3436.      1...
# 2  16.0   8.   304.0      150.0      3433.      1...
# 3  17.0   8.   302.0      140.0      3449.      1...
# 4  15.0   8.   429.0      198.0      4341.      1...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 1 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   18.0   8.   307.0      130.0      3504.      12.0   70.  1.	"chevrolet chevelle malibu"  405 non-null    object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# Vemos que el archivo no cargó correctamente. Para que cargue correctamente debemos especificar que no tiene encabezado y que el separador es el espacio en blanco. Esto lo hacemos con los parámetros `header=None` y `sep=r"\s+"`.

# %%
df = pd.read_csv(
    "/content/auto-mpg.data",
    header=None,
    sep=r"\s+"
    )

df.head()
# Out:
#       0    1      2      3       4     5     6    7                          8
# 0  18.0  8.0  307.0  130.0  3504.0  12.0  70.0  1.0  chevrolet chevelle malibu
# 1  15.0  8.0  350.0  165.0  3693.0  11.5  70.0  1.0          buick skylark 320
# 2  18.0  8.0  318.0  150.0  3436.0  11.0  70.0  1.0         plymouth satellite
# 3  16.0  8.0  304.0  150.0  3433.0  12.0  70.0  1.0              amc rebel sst
# 4  17.0  8.0  302.0  140.0  3449.0  10.5  70.0  1.0                ford torino

# %% [markdown]
# Cómo no pasamos los nombres de las columnas en el parámetro `names`, Pandas les asigna nombres por defecto que son números enteros. Pero si usamos el parámetro `names` podemos especificar los nombres de las columnas.
#
# También podríamos cambiar el nombre de las columnas después de cargar el archivo, modificando el atributo `columns` del DataFrame.

# %%
df.columns = [
	'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
	'acceleration', 'model_year', 'origin', 'car_name'
]
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0        8.0         307.0       130.0  3504.0          12.0
# 1  15.0        8.0         350.0       165.0  3693.0          11.5
# 2  18.0        8.0         318.0       150.0  3436.0          11.0
# 3  16.0        8.0         304.0       150.0  3433.0          12.0
# 4  17.0        8.0         302.0       140.0  3449.0          10.5
#
#    model_year  origin                   car_name
# 0        70.0     1.0  chevrolet chevelle malibu
# 1        70.0     1.0          buick skylark 320
# 2        70.0     1.0         plymouth satellite
# 3        70.0     1.0              amc rebel sst
# 4        70.0     1.0                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     406 non-null    float64
#  2   displacement  406 non-null    float64
#  3   horsepower    400 non-null    float64
#  4   weight        406 non-null    float64
#  5   acceleration  406 non-null    float64
#  6   model_year    406 non-null    float64
#  7   origin        406 non-null    float64
#  8   car_name      406 non-null    object
# dtypes: float64(8), object(1)
# memory usage: 28.7+ KB

# %% [markdown]
# # Detección de datos nulos y duplicados

# %% [markdown]
# Los datos nulos son datos desconocidos, es decir valores de variables de los que no se tiene información para algún registro.
#
# Pandas es capaz de reconocer autómaticamente algunas secuencias de caracteres como datos nulos, como “ ”, “#N/A”, “#N/A N/A”, “#NA”, “-1.#IND”, “-1.#QNAN”, “-NaN”, “-nan”, “1.#IND”, “1.#QNAN”, “<NA>”, “N/A”, “NA”, “NULL”, “NaN”, “None”, “n/a”, “nan”, “null”.
#
# Los métodos `isnull()` y `notnull()` nos permiten detectar datos nulos y no nulos, respectivamente.

# %%
df.isnull().sum()
# Out:
# mpg             8
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car_name        0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# mpg             398
# cylinders       406
# displacement    406
# horsepower      400
# weight          406
# acceleration    406
# model_year      406
# origin          406
# car_name        406
# dtype: int64

# %% [markdown]
# A veces, los datos nulos no son reconocidos por Pandas, por lo que es necesario especificarlos, usando el parámetro `na_values`.

# %%
file_path = "/content/adult_modified.data"

df = pd.read_csv(
    file_path,
    header=None,
    names=[
        'age',
        'workclass',
        'fnlwgt',
        'education',
        'education-num',
        'marital-status',
        'occupation',
        'relationship',
        'race',
        'sex',
        'capital-gain',
        'capital-loss',
        'hours-per-week',
        'native-country',
        'income',
    ],
    )

df.head()
# Out:
#    age          workclass  fnlwgt   education education-num  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors             ?
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain capital-loss hours-per-week  native-country  income
# 0          2174            0              ?   United-States   <=50K
# 1             0            0             13   United-States   <=50K
# 2             0            0             40   United-States   <=50K
# 3             0            0             40   United-States   <=50K
# 4             0            0             40            Cuba   <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  object
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  object
#  12  hours-per-week  32561 non-null  object
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(3), object(12)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# Analizando la estructura del dataset, se puede observar que las columnas "education-num" y "hours-per-week" son numéricas, pero Pandas no las identifica así. Esto se puede deber a que en el archivo original, algunas celdas contienen el valor "?", lo que impide que Pandas las identifique como numéricas. Esto se puede arreglar de 2 formas:
# 1. Usando el parámetro na_values="?" al método read_csv.
# 2. Cambiando el tipo de dato de las columnas después de cargar el dataset, y forzando la conversión a numérico.

# %%
df['education-num'] = pd.to_numeric(df['education-num'], errors='coerce')
df['hours-per-week'] = pd.to_numeric(df['hours-per-week'], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32560 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  object
#  12  hours-per-week  32559 non-null  float64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     1
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    2
# native-country    0
# income            0
# dtype: int64

# %%
df = pd.read_csv(
    file_path,
    header=None,
    names=[
        'age',
        'workclass',
        'fnlwgt',
        'education',
        'education-num',
        'marital-status',
        'occupation',
        'relationship',
        'race',
        'sex',
        'capital-gain',
        'capital-loss',
        'hours-per-week',
        'native-country',
        'income',
    ],
    na_values=[' ?', ' '],
    )

df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors           13.0
# 1   50   Self-emp-not-inc   83311   Bachelors           13.0
# 2   38            Private  215646     HS-grad            9.0
# 3   53            Private  234721        11th            7.0
# 4   28            Private  338409   Bachelors            NaN
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174           0.0             NaN   United-States   <=50K
# 1             0           0.0            13.0   United-States   <=50K
# 2             0           0.0            40.0   United-States   <=50K
# 3             0           0.0            40.0   United-States   <=50K
# 4             0           0.0            40.0            Cuba   <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32560 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32560 non-null  float64
#  12  hours-per-week  32559 non-null  float64
#  13  native-country  31978 non-null  object
#  14  income          32561 non-null  object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        1
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         1
# hours-per-week       2
# native-country     583
# income               0
# dtype: int64

# %% [markdown]
# Pandas también tiene métodos para identificar y gestionar registros duplicados:

# %%
print('Número de registros duplicados: ', df.duplicated().sum())
# Out:
# Número de registros duplicados:  24

# %% [markdown]
# # Ejercicio
#
# 1. Cargue el archivo "Telco_customer_churn.csv", cuidando que quede correctamente cargado.
#
# 2. Indique cuantos registros y cuantas columnas tiene el dataframe creado.
#
# 3. Indique que variables son categóricas. ¿Es consistente con el contenido de las variables?
#
# 4. Indique en que variables hay datos nulos.
#
# 5. Indique si hay registros duplicados.
